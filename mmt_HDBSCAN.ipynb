# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as mn
from sklearn import cluster, preprocessing, metrics
import scipy 
import seaborn as sns
import folium
import hdbscan

# %matplotlib inline

# %%
dataset=pd.read_csv("makemytrip_com-travel_sample.csv")
dataset.head()
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_18428\1246907446.py:1: DtypeWarning: Columns (12,14,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset=pd.read_csv("makemytrip_com-travel_sample.csv")
#                     area     city country  crawl_date  \
# 0      Hardasji Ki Magri  Udaipur   India  21-06-2016
# 1          Near Nai Gaon  Udaipur   India  21-06-2016
# 2  Near Bagore Ki Haveli  Udaipur   India  21-06-2016
# 3                  Dabok  Udaipur   India  21-06-2016
# 4           East Udaipur  Udaipur   India  21-06-2016
#
#                                      highlight_value  \
# 0                                       {{facility}}
# 1                                       {{facility}}
# 2                                       {{facility}}
# 3  Airport Transfer|Car rental|Conference Hall|Cu...
# 4                                       {{facility}}
#
#                                       hotel_overview hotel_star_rating  \
# 0  |Zion Home Stay is located in a city that sets...            1 star
# 1  | Araliayas Resorts is a 3 star hotel located ...            3 star
# 2  |A 2 star property is located at 24 km from Ma...            2 star
# 3  |SNP House Airport Hotel And Restaurant is loa...            1 star
# 4  | Hotel Pichola Haveli is situated in the beau...            2 star
#
#                                           image_urls in_your_room  \
# 0                                                NaN    {{value}}
# 1                                                NaN    {{value}}
# 2                                                NaN    {{value}}
# 3  //imghtlak.mmtcdn.com/images/hotels/2014071815...          NaN
# 4                                                NaN    {{value}}
#
#   is_value_plus  ...  property_type  qts           query_time_stamp  \
# 0            no  ...          Hotel  NaN  2016-06-21 04:06:50 +0000
# 1            no  ...          Hotel  NaN  2016-06-21 04:06:50 +0000
# 2            no  ...          Hotel  NaN  2016-06-21 04:06:50 +0000
# 3            no  ...          Hotel  NaN  2016-06-21 04:06:50 +0000
# 4            no  ...          Hotel  NaN  2016-06-21 04:06:50 +0000
#
#   room_types site_review_count site_review_rating    sitename state  \
# 0        NaN                /5                4.5  makemytrip   NaN
# 1        NaN                /5                4.5  makemytrip   NaN
# 2        NaN                /5                NaN  makemytrip   NaN
# 3  `standard                /5                NaN  makemytrip   NaN
# 4        NaN                /5                3.7  makemytrip   NaN
#
#   traveller_rating                           uniq_id
# 0              NaN  78ddf880bd7937d384ff278cc5b39d6e
# 1              NaN  9f9f9cbb2f7df8089b63d5cdeb257944
# 2              NaN  b314bb7fa8bfb1ed306f517be21d729e
# 3              NaN  e6f5bb3c2d76a78d978b9ceb0e31ec56
# 4              NaN  63072c301427b6ca450d31eea127bcf0
#
# [5 rows x 33 columns]

# %%
dataset.columns
# Out:
# Index(['area', 'city', 'country', 'crawl_date', 'highlight_value',
#        'hotel_overview', 'hotel_star_rating', 'image_urls', 'in_your_room',
#        'is_value_plus', 'latitude', 'longitude', 'mmt_holidayiq_review_count',
#        'mmt_location_rating', 'mmt_review_count', 'mmt_review_rating',
#        'mmt_review_score', 'mmt_traveller_type_review_count',
#        'mmt_tripadvisor_count', 'pageurl', 'property_address', 'property_id',
#        'property_name', 'property_type', 'qts', 'query_time_stamp',
#        'room_types', 'site_review_count', 'site_review_rating', 'sitename',
#        'state', 'traveller_rating', 'uniq_id'],
#       dtype='object')

# %%
z= ["latitude","longitude", 'site_review_rating', 'room_types', 'property_address']
data= dataset[z]
df=pd.DataFrame(data)
df
# Out:
#         latitude  longitude  site_review_rating  \
# 0      24.581788  73.667805                 4.5
# 1      24.544342  73.644242                 4.5
# 2      24.579942  73.681953                 NaN
# 3      24.622607  73.855194                 NaN
# 4      24.580100  73.682200                 3.7
# ...          ...        ...                 ...
# 20031  11.769778  76.001652                 NaN
# 20032  25.310400  83.010200                 NaN
# 20033  12.307097  76.667002                 NaN
# 20034  11.607579  76.082773                 NaN
# 20035  17.739367  83.307634                 NaN
#
#                           room_types  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                          `standard
# 4                                NaN
# ...                              ...
# 20031     Cottage (Standard Cottage)
# 20032  Ac Single Room|Ac Double Room
# 20033                  Single|Double
# 20034                  Standard Room
# 20035            Bollywood|Hollywood
#
#                                         property_address
# 0      Zion, F-17, Haridas Ji Ki Magri, Near Bal Vina...
# 1                    Udaipur-Jhadol Road , Near Nai Gaon
# 2      23/208 Gangaur Ghat Near Bagore Ki Haveli , Ne...
# 3          Opp GITS, NH-76, Bamaniya Khet, Dabok , Dabok
# 4      64 Ghangour Ghat, Opp Bagore Ki Haveli , East ...
# ...                                                  ...
# 20031  Thonichal, Mananthavady , Thonichal, Mananthavady
# 20032  D 8/35, Kalika Gali, Near Kashi Vishvenath Tem...
# 20033              Vasanth Mahal Road, Nazarbad , Mysore
# 20034                          Near Town Koram , Wayanad
# 20035  D.No:50-50-20/A, T.P.T Colony , Opp: APSEB Sub...
#
# [20036 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# latitude                 22
# longitude                21
# site_review_rating    19482
# room_types             4880
# property_address          4
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# latitude              0
# longitude             0
# site_review_rating    0
# room_types            0
# property_address      0
# dtype: int64

# %%
lower_bound = df['latitude'].quantile(0.01)
upper_bound = df['latitude'].quantile(0.99)
dfcopy2 = df[(df['latitude'] > lower_bound) & (df['latitude'] < upper_bound)]

lower_bound = df['longitude'].quantile(0.01)
upper_bound = df['longitude'].quantile(0.99)
df = df[(df['longitude'] > lower_bound) & (df['longitude'] < upper_bound)]

# %%
plots = [df['latitude'], df['longitude']]
colors=["red", "blue"]
plt.figure(figsize=(15,5))
box = plt.boxplot(plots, labels=['latitude', 'longitude'], patch_artist=True)
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
coords = df[['latitude', 'longitude']].values

min_cluster_sizes = range(2, 16)

silhouette_scores = []

for min_cluster_size in min_cluster_sizes:
    hdbscan_model = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size)
    clusters = hdbscan_model.fit_predict(coords)
    silhouette_scores.append(metrics.silhouette_score(coords, clusters))

plt.figure(figsize=(15,5))
plt.plot(min_cluster_sizes, silhouette_scores, marker='o')
plt.xlabel('min_cluster_size')
plt.ylabel('Silhouette score')
plt.grid()
plt.show()

# %%
hdb = hdbscan.HDBSCAN(min_cluster_size=14).fit(coords)

p = sns.scatterplot(data=df, x="latitude", y="longitude", hue=hdb.labels_, legend="full", palette="deep")
sns.move_legend(p, "upper right", bbox_to_anchor=(1.17, 1.2), title='Clusters')
plt.show()

# %%
X = df[["latitude","longitude"]]
model = hdbscan.HDBSCAN(min_cluster_size=14)
## clustering
dtf_X = X.copy()
dtf_X["cluster"] = model.fit_predict(X)
df[["cluster"]] = dtf_X[["cluster"]]
df
# Out:
#         latitude  longitude  site_review_rating  \
# 1684   12.986415  77.595370                 4.6
# 1685   12.936044  77.621610                 4.3
# 1686   19.115473  72.889134                 3.3
# 1730   26.864600  75.589900                 4.8
# 2121   30.459626  78.063851                 4.6
# ...          ...        ...                 ...
# 18890  20.296100  85.824500                 4.2
# 18891  30.226976  74.942411                 4.6
# 18893  11.388123  75.718613                 3.8
# 18894  20.268086  85.843338                 3.5
# 18896  21.210922  81.353760                 4.3
#
#                                               room_types  \
# 1684                                       Deluxe|Studio
# 1685                                     Standard|Deluxe
# 1686                                  Economy Room|Suite
# 1730                                              Deluxe
# 2121   Standard (non View)|Super Deluxe ( View Side )...
# ...                                                  ...
# 18890  Standard Non Ac|Standard AC|Deluxe Ac|Super De...
# 18891                        Deluxe Room|Executive Suite
# 18893                            Sea Facing|Beach Facing
# 18894  Economy Non A/c Room|Royal Deluxe Room Non A/c...
# 18896                                      Deluxe Non Ac
#
#                                         property_address  cluster
# 1684               34, Cunningham Road , Cunningham Road        0
# 1685   No 52, 5th Cross, 6th Block, Next to Vijaya Ba...        0
# 1686   Saki Vihar Complex, Opp. Saki Vihar Road, Saki...        0
# 1730   Village Sanjharia, Before Toll gate, Via Vatik...        1
# 2121         Monarch Hotel, Gandhi Chowk , Library Chowk        1
# ...                                                  ...      ...
# 18890  366/A, Old Station Bazar, In front of Railway ...       -1
# 18891                    Barnala , Barnala Bye Paas Road        1
# 18893      PO Chemancherry, Thoovappara, Kappad , Kappad        0
# 18894  122/A New Station Square, Kharvelnagar , Railw...       -1
# 18896                  Hotel Amantran, GE Road , GE Road       -1
#
# [145 rows x 6 columns]

# %%
x, y = "latitude", "longitude"
color = "cluster"
size = "site_review_rating"
popup = "property_address"
data = df.copy()
## create color column
lst_elements = sorted(list(df[color].unique()))
lst_colors = ['#%06X' % np.random.randint(0, 0xFFFFFF) for i in 
              range(len(lst_elements))]
data["color"] = data[color].apply(lambda x: 
                lst_colors[lst_elements.index(x)])
## create size column (scaled)
scaler = preprocessing.MinMaxScaler(feature_range=(3,15))
data["size"] = scaler.fit_transform(
               data[size].values.reshape(-1,1)).reshape(-1)
## initialize the map with the starting location
map_ = folium.Map(location=[df['latitude'].mean(), df['longitude'].mean()], tiles="cartodbpositron",
                  zoom_start=5)
## add points
data.apply(lambda row: folium.CircleMarker(
           location=[row[x],row[y]], 
           color=row["color"], fill=True,popup=row[popup],
           radius=row["size"]).add_to(map_), axis=1)
## add html legend
legend_html = """<div style="position:fixed; bottom:10px; left:10px; border:2px solid black; z-index:9999; font-size:14px;">&nbsp;<b>"""+color+""":</b><br>"""
for i in lst_elements:
     legend_html = legend_html+"""&nbsp;<i class="fa fa-circle 
     fa-1x" style="color:"""+lst_colors[lst_elements.index(i)]+"""">
     </i>&nbsp;"""+str(i)+"""<br>"""
legend_html = legend_html+"""</div>"""
map_.get_root().html.add_child(folium.Element(legend_html))
## plot the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15d2205e9bbaa309c97680f440c7d991 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position:fixed; bottom:10px; left:10px; border:2px solid black; z-index:9999; font-size:14px;&quot;&gt;&amp;nbsp;&lt;b&gt;cluster:&lt;/b&gt;&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#9BFC72&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;-1&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#537CA1&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;0&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#3F6754&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;1&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15d2205e9bbaa309c97680f440c7d991&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15d2205e9bbaa309c97680f440c7d991 = L.map(
#                 &quot;map_15d2205e9bbaa309c97680f440c7d991&quot;,
#                 {
#                     center: [24.977774810896555, 77.8589683782069],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b089e268273883ba5f89dac25e618614 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_15d2205e9bbaa309c97680f440c7d991);
#
#
#             var circle_marker_1e0a78cbfabf0bc786883cd221de9a5a = L.circleMarker(
#                 [12.986415, 77.59537],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#537CA1&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#537CA1&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14.04, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_15d2205e9bbaa309c97680f440c7d991);
#
#
#         var popup_ef6b714b09c65e2a7fa77edf11d6dec2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f80148b3a409eb83c3c3526703c41316 = $(`&lt;div id=&quot;html_f80148b3a409eb83c3c3526703c41316&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;34, Cunningham Road , Cunningham Road&lt;/div&gt;`)[0];
#                 popup_ef6b714b09c65e2a7fa77edf11d6dec2.setContent(html_f80148b3a409eb83c3c3526703c41316);
#
#
#
#         circle_marker_1e0a78cbfabf0bc786883cd221de9a5a.bindPopup(popup_ef6b714b09c65e2a7fa77edf11d6dec2)
#         ;
#
#
#
#
#             var circle_marker_bcedafdf208fef6b482805886271d94e = L.circleMarker(
#                 [12.936044, 77.62161],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#537CA1&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#537CA1&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.319999999999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_15d2205e9bbaa309c97680f440c7d991);
#
#
#         var popup_58ea41981990dca9f46dae515619e4d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be3e3ec7da3fd8e1c3e131072d1a7d88 = $(`&lt;div id=&quot;html_be3e3ec7da3fd8e1c3e131072d1a7d88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;No 52, 5th Cross, 6th Block, Next to Vijaya Bank, 60ft Road, Koramangala , Koramangala&lt;/div&gt;`)[0];
#                 popup_58ea41981990dca9f46dae515619e4d2.setContent(html_be3e3ec7da3fd8e1c3e131072d1a7d88);
#
#
#
#         circle_marker_bcedafdf208fef6b482805886271d94e.bindPopup(popup_58ea41981990dca9f46dae515619e4d2)
#         ;
#
#
#
#
#             var circle_marker_83cbdd0cc245ab9bf61cb3ed286ff9fa = L.circleMarker(
#                 [19.115473, 72.889134],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#537CA1&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#537CA1&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.919999999999998, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_15d2205e9bbaa309c97680f44
